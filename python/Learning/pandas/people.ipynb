# %%
people = {
    'first': ['Corey', 'Jane', 'John'],
    'last': ['Schafer', 'Doe', 'Smith'],
    'email': ['CoreySchafer@gamil.com', 'JaneDoe@gamil.com', 'JohnSmith@gamil.com']
}

# %%
import pandas as pd
import numpy as np

# %%
df = pd.DataFrame(people)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gamil.com
# 1   Jane      Doe       JaneDoe@gamil.com
# 2   John    Smith     JohnSmith@gamil.com

# %%
def update_email(email):
    return email.upper()

# %%
df['email'].apply(update_email)
# Out:
# 0    COREYSCHAFER@GAMIL.COM
# 1         JANEDOE@GAMIL.COM
# 2       JOHNSMITH@GAMIL.COM
# Name: email, dtype: str

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gamil.com
# 1   Jane      Doe       JaneDoe@gamil.com
# 2   John    Smith     JohnSmith@gamil.com

# %%
df['email'] = df['email'].apply(update_email)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  COREYSCHAFER@GAMIL.COM
# 1   Jane      Doe       JANEDOE@GAMIL.COM
# 2   John    Smith     JOHNSMITH@GAMIL.COM

# %%
df['email'] = df['email'].apply(lambda x: x.lower())

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  coreyschafer@gamil.com
# 1   Jane      Doe       janedoe@gamil.com
# 2   John    Smith     johnsmith@gamil.com

# %%
df['email'].apply(len)
# Out:
# 0    22
# 1    17
# 2    19
# Name: email, dtype: int64

# %%
df.apply(len, axis='columns')
# Out:
# 0    3
# 1    3
# 2    3
# dtype: int64

# %%
df.apply(pd.Series.min)
# Out:
# first                     Corey
# last                        Doe
# email    coreyschafer@gamil.com
# dtype: str

# %%
df.map(str.lower)
# Out:
#    first     last                   email
# 0  corey  schafer  coreyschafer@gamil.com
# 1   jane      doe       janedoe@gamil.com
# 2   john    smith     johnsmith@gamil.com

# %%
df['first'].map({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2      NaN
# Name: first, dtype: str

# %%
df['first'].replace({'Corey': 'Chris', 'Jane': 'Mary'})
# Out:
# 0    Chris
# 1     Mary
# 2     John
# Name: first, dtype: str

# %%
df['first'] + ' ' + df['last']
# Out:
# 0    Corey Schafer
# 1         Jane Doe
# 2       John Smith
# dtype: str

# %%
df['full_name'] = df['first'] + ' ' + df['last']

# %%
df
# Out:
#    first     last                   email      full_name
# 0  Corey  Schafer  coreyschafer@gamil.com  Corey Schafer
# 1   Jane      Doe       janedoe@gamil.com       Jane Doe
# 2   John    Smith     johnsmith@gamil.com     John Smith

# %%
df.drop(columns=['first', 'last'], inplace=True)

# %%
df
# Out:
#                     email      full_name
# 0  coreyschafer@gamil.com  Corey Schafer
# 1       janedoe@gamil.com       Jane Doe
# 2     johnsmith@gamil.com     John Smith

# %%
df['full_name'].str.split(' ', expand=True)
# Out:
#        0        1
# 0  Corey  Schafer
# 1   Jane      Doe
# 2   John    Smith

# %%
df[['first', 'last']] = df['full_name'].str.split(' ', expand=True)

# %%
df
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gamil.com  Corey Schafer  Corey  Schafer
# 1       janedoe@gamil.com       Jane Doe   Jane      Doe
# 2     johnsmith@gamil.com     John Smith   John    Smith

# %%
pd.concat([df, pd.DataFrame([{'first': 'Tony'}])], ignore_index=True)
# Out:
#                     email      full_name  first     last
# 0  coreyschafer@gamil.com  Corey Schafer  Corey  Schafer
# 1       janedoe@gamil.com       Jane Doe   Jane      Doe
# 2     johnsmith@gamil.com     John Smith   John    Smith
# 3                     NaN            NaN   Tony      NaN

# %%
people = {
    'first': ['Tony','Steve'],
    'last': ['Stack', 'Rogers'],
    'email': ['IronMan@avenage.com', 'Cap@avenage.com']
}
df2 = pd.DataFrame(people)

# %%
df2
# Out:
#    first    last                email
# 0   Tony   Stack  IronMan@avenage.com
# 1  Steve  Rogers      Cap@avenage.com

# %%
pd.concat([df, df2],ignore_index=True)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gamil.com
# 1   Jane      Doe       JaneDoe@gamil.com
# 2   John    Smith     JohnSmith@gamil.com
# 3   Tony    Stack     IronMan@avenage.com
# 4  Steve   Rogers         Cap@avenage.com

# %%
df = pd.concat([df, df2],ignore_index=True)

# %%
df
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gamil.com
# 1   Jane      Doe       JaneDoe@gamil.com
# 2   John    Smith     JohnSmith@gamil.com
# 3   Tony    Stack     IronMan@avenage.com
# 4  Steve   Rogers         Cap@avenage.com

# %%
df.drop(index=4)
# Out:
#    first     last                   email
# 0  Corey  Schafer  CoreySchafer@gamil.com
# 1   Jane      Doe       JaneDoe@gamil.com
# 2   John    Smith     JohnSmith@gamil.com
# 3   Tony    Stack     IronMan@avenage.com

# %%
people = {
    'first': ['Corey', 'Jane', 'John', 'Chris', np.nan, None, 'NA'],
    'last': ['Schafer', 'Doe', 'Doe', 'Schafer', np.nan, np.nan, 'Missing'],
    'email': ['CoreySchafer@gmail.com', 'JaneDOe@email.com', 'JoneDoe@email.com', None, np.nan, 'Anonymous@email.com', 'NA'],
    'age': ['33', '55', '63', '36', None, None, 'Missing']
}

# %%
df = pd.DataFrame(people)

df.replace('NA', np.nan, inplace=True)
df.replace('Missing', np.nan, inplace=True)
# Out:
#    first     last                   email  age
# 0  Corey  Schafer  CoreySchafer@gmail.com   33
# 1   Jane      Doe       JaneDOe@email.com   55
# 2   John      Doe       JoneDoe@email.com   63
# 3  Chris  Schafer                     NaN   36
# 4    NaN      NaN                     NaN  NaN
# 5    NaN      NaN     Anonymous@email.com  NaN
# 6    NaN      NaN                     NaN  NaN

# %%
df
# Out:
#    first     last                   email  age
# 0  Corey  Schafer  CoreySchafer@gmail.com   33
# 1   Jane      Doe       JaneDOe@email.com   55
# 2   John      Doe       JoneDoe@email.com   63
# 3  Chris  Schafer                     NaN   36
# 4    NaN      NaN                     NaN  NaN
# 5    NaN      NaN     Anonymous@email.com  NaN
# 6    NaN      NaN                     NaN  NaN

# %%
df.dropna()
# Out:
#    first     last                   email age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33
# 1   Jane      Doe       JaneDOe@email.com  55
# 2   John      Doe       JoneDoe@email.com  63

# %%
df.dropna(axis='index', how='any')
# Out:
#    first     last                   email age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33
# 1   Jane      Doe       JaneDOe@email.com  55
# 2   John      Doe       JoneDoe@email.com  63

# %%
df.dropna(axis='index', how='all', subset=['last', 'email'])
# Out:
#    first     last                   email  age
# 0  Corey  Schafer  CoreySchafer@gmail.com   33
# 1   Jane      Doe       JaneDOe@email.com   55
# 2   John      Doe       JoneDoe@email.com   63
# 3  Chris  Schafer                     NaN   36
# 5    NaN      NaN     Anonymous@email.com  NaN

# %%
df.isna()
# Out:
#    first   last  email    age
# 0  False  False  False  False
# 1  False  False  False  False
# 2  False  False  False  False
# 3  False  False   True  False
# 4   True   True   True   True
# 5   True   True  False   True
# 6   True   True   True   True

# %%
df.fillna(0)
# Out:
#    first     last                   email age
# 0  Corey  Schafer  CoreySchafer@gmail.com  33
# 1   Jane      Doe       JaneDOe@email.com  55
# 2   John      Doe       JoneDoe@email.com  63
# 3  Chris  Schafer                       0  36
# 4      0        0                       0   0
# 5      0        0     Anonymous@email.com   0
# 6      0        0                       0   0

# %%
df.dtypes
# Out:
# first    str
# last     str
# email    str
# age      str
# dtype: object

# %%
 df['age'] = df['age'].astype(float)

# %%
df.dtypes
# Out:
# first        str
# last         str
# email        str
# age      float64
# dtype: object

# %%
df['age'].mean()
# Out:
# np.float64(46.75)
